# %%
import pandas as pd

# %%
raw_data.dtypes
# Out:
# Benchmark                      object
# Hardware Vendor\t              object
# System                         object
# Peak Result                   float64
# Base Result                   float64
# Energy Peak Result            float64
# Energy Base Result            float64
# # Cores                         int64
# # Chips                         int64
# # Enabled Threads Per Core      int64
# Processor                      object
# Processor MHz                   int64
# CPU(s) Orderable               object
# Parallel                       object
# Base Pointer Size              object
# Peak Pointer Size              object
# 1st Level Cache                object
# 2nd Level Cache                object
# 3rd Level Cache                object
# Other Cache                    object
# Memory                         object
# Storage                        object
# Operating System               object
# File System                    object
# Compiler                       object
# ...

# %%
raw_data
# Out:
#          Benchmark      Hardware Vendor\t  \
# 0         CINT2017       ASRock Rack Inc.
# 1         CINT2017  ASUSTeK Computer Inc.
# 2         CINT2017  ASUSTeK Computer Inc.
# 3         CINT2017  ASUSTeK Computer Inc.
# 4         CINT2017  ASUSTeK Computer Inc.
# ...            ...                    ...
# 31101  CFP2017rate                xFusion
# 31102  CFP2017rate                xFusion
# 31103  CFP2017rate                xFusion
# 31104  CFP2017rate                xFusion
# 31105  CFP2017rate                xFusion
#
#                                                   System  Peak Result  \
# 0               1U4LW-X570 RPSU AMD Ryzen 7 5800X,3.8GHz        15.30
# 1      ASUS ESC4000A-E10(KRPG-U8) Server System 2.60 ...         9.09
# 2      ASUS ESC8000 G4(Z11PG-D24) Server System (1.90...         5.15
# 3      ASUS ESC8000 G4(Z11PG-D24) Server System (1.90...         5.22
# 4      ASUS ESC8000 G4(Z11PG-D24) Server System (1.90...        10.30
# ...

# %%
arr = np.ones(8000)

# %%
arr[0] = 500

# %%
std=arr.std()
mean = arr.mean()

# %%
mean
# Out:
# 1.062375

# %%
std
# Out:
# 5.57864090611459

# %%
arr = (arr-mean) / std

# %%
arr
# Out:
# array([ 8.94371288e+01, -1.11810387e-02, -1.11810387e-02, ...,
#        -1.11810387e-02, -1.11810387e-02, -1.11810387e-02])

# %%
np.log10(1)
# Out:
# 0.0

# %%
np.log(np.e)
# Out:
# 1.0

# %%
np.log1p(np.e)
# Out:
# 1.3132616875182228
